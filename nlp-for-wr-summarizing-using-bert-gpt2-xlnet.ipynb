# %% [markdown]
# <a class="anchor" id="0"></a>
# # [NLP : Reports & News Classification](https://www.kaggle.com/vbmokin/nlp-reports-news-classification)
# ## Automatic Environmental Reports & News Classification (English)

# %% [markdown]
# # Acknowledgements
#
# This notebook uses such good notebooks:
# * BERT, GPT2, XLNET summarizing from the notebook [Text Summarization using BERT, GPT2,XLNET](https://www.kaggle.com/pemagrg/text-summarization-using-bert-gpt2-xlnet)
# * data download from my notebook [NLP for EN : BERT Classification for Water Report](https://www.kaggle.com/vbmokin/nlp-for-en-bert-classification-for-water-report)
#
# My dataset [NLP : Reports & News Classification](https://www.kaggle.com/vbmokin/nlp-reports-news-classification)

# %% [markdown]
# <a class="anchor" id="0.1"></a>
# ## Table of Contents
#
# 1. [Install and import libraries](#1)
# 1. [Download data](#2)
# 1. [Text Summarizing](#3)
#     -  [BERT Summarizing](#3.1)
#     -  [GPT-2 Summarizing](#3.2)
#     -  [XLNet Summarizing](#3.3)
# 1. [Results](#4)

# %% [markdown]
# ## 1. Install and import libraries <a class="anchor" id="1"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# %%time
# !pip install bert-extractive-summarizer==0.7.1
# Out:
# Requirement already satisfied: bert-extractive-summarizer==0.7.1 in a:\python3\lib\site-packages (0.7.1)
# Requirement already satisfied: spacy in a:\python3\lib\site-packages (from bert-extractive-summarizer==0.7.1) (3.4.1)
# Requirement already satisfied: scikit-learn in a:\python3\lib\site-packages (from bert-extractive-summarizer==0.7.1) (1.1.1)
# Requirement already satisfied: transformers in a:\python3\lib\site-packages (from bert-extractive-summarizer==0.7.1) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in a:\python3\lib\site-packages (from scikit-learn->bert-extractive-summarizer==0.7.1) (1.9.0)
# Requirement already satisfied: joblib>=1.0.0 in a:\python3\lib\site-packages (from scikit-learn->bert-extractive-summarizer==0.7.1) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in a:\python3\lib\site-packages (from scikit-learn->bert-extractive-summarizer==0.7.1) (1.23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in a:\python3\lib\site-packages (from scikit-learn->bert-extractive-summarizer==0.7.1) (3.1.0)
# Requirement already satisfied: setuptools in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (58.1.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (1.9.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (8.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (4.64.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (3.3.0)
# Requirement already satisfied: jinja2 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (2.28.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (3.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (3.0.10)
# Requirement already satisfied: packaging>=20.0 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (1.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (0.4.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (2.4.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (1.0.3)
# Requirement already satisfied: pathy>=0.3.5 in a:\python3\lib\site-packages (from spacy->bert-extractive-summarizer==0.7.1) (0.6.2)
# Requirement already satisfied: sacremoses in a:\python3\lib\site-packages (from transformers->bert-extractive-summarizer==0.7.1) (0.0.53)
# Requirement already satisfied: boto3 in a:\python3\lib\site-packages (from transformers->bert-extractive-summarizer==0.7.1) (1.24.82)
# Requirement already satisfied: regex in a:\python3\lib\site-packages (from transformers->bert-extractive-summarizer==0.7.1) (2022.7.25)
# Requirement already satisfied: sentencepiece in a:\python3\lib\site-packages (from transformers->bert-extractive-summarizer==0.7.1) (0.1.97)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in a:\python3\lib\site-packages (from packaging>=20.0->spacy->bert-extractive-summarizer==0.7.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in a:\python3\lib\site-packages (from pathy>=0.3.5->spacy->bert-extractive-summarizer==0.7.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in a:\python3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy->bert-extractive-summarizer==0.7.1) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in a:\python3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer==0.7.1) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in a:\python3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer==0.7.1) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in a:\python3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer==0.7.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in a:\python3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer==0.7.1) (2022.6.15)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in a:\python3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy->bert-extractive-summarizer==0.7.1) (0.7.8)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in a:\python3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy->bert-extractive-summarizer==0.7.1) (0.0.2)
# Requirement already satisfied: colorama in a:\python3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy->bert-extractive-summarizer==0.7.1) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in a:\python3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy->bert-extractive-summarizer==0.7.1) (8.1.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in a:\python3\lib\site-packages (from boto3->transformers->bert-extractive-summarizer==0.7.1) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in a:\python3\lib\site-packages (from boto3->transformers->bert-extractive-summarizer==0.7.1) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.82 in a:\python3\lib\site-packages (from boto3->transformers->bert-extractive-summarizer==0.7.1) (1.27.82)
# Requirement already satisfied: MarkupSafe>=2.0 in a:\python3\lib\site-packages (from jinja2->spacy->bert-extractive-summarizer==0.7.1) (2.1.1)
# Requirement already satisfied: six in a:\python3\lib\site-packages (from sacremoses->transformers->bert-extractive-summarizer==0.7.1) (1.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in a:\python3\lib\site-packages (from botocore<1.28.0,>=1.27.82->boto3->transformers->bert-extractive-summarizer==0.7.1) (2.8.2)
# CPU times: total: 15.6 ms
# Wall time: 2.71 s

# %%
# %%time
# !pip install transformers==2.2.0
# Out:
# Requirement already satisfied: transformers==2.2.0 in a:\python3\lib\site-packages (2.2.0)
# Requirement already satisfied: regex in a:\python3\lib\site-packages (from transformers==2.2.0) (2022.7.25)
# Requirement already satisfied: tqdm in a:\python3\lib\site-packages (from transformers==2.2.0) (4.64.0)
# Requirement already satisfied: boto3 in a:\python3\lib\site-packages (from transformers==2.2.0) (1.24.82)
# Requirement already satisfied: requests in a:\python3\lib\site-packages (from transformers==2.2.0) (2.28.1)
# Requirement already satisfied: sentencepiece in a:\python3\lib\site-packages (from transformers==2.2.0) (0.1.97)
# Requirement already satisfied: numpy in a:\python3\lib\site-packages (from transformers==2.2.0) (1.23.1)
# Requirement already satisfied: sacremoses in a:\python3\lib\site-packages (from transformers==2.2.0) (0.0.53)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in a:\python3\lib\site-packages (from boto3->transformers==2.2.0) (1.0.1)
# Requirement already satisfied: botocore<1.28.0,>=1.27.82 in a:\python3\lib\site-packages (from boto3->transformers==2.2.0) (1.27.82)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in a:\python3\lib\site-packages (from boto3->transformers==2.2.0) (0.6.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in a:\python3\lib\site-packages (from requests->transformers==2.2.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in a:\python3\lib\site-packages (from requests->transformers==2.2.0) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in a:\python3\lib\site-packages (from requests->transformers==2.2.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in a:\python3\lib\site-packages (from requests->transformers==2.2.0) (1.26.11)
# Requirement already satisfied: click in a:\python3\lib\site-packages (from sacremoses->transformers==2.2.0) (8.1.3)
# Requirement already satisfied: six in a:\python3\lib\site-packages (from sacremoses->transformers==2.2.0) (1.16.0)
# Requirement already satisfied: joblib in a:\python3\lib\site-packages (from sacremoses->transformers==2.2.0) (1.1.0)
# Requirement already satisfied: colorama in a:\python3\lib\site-packages (from tqdm->transformers==2.2.0) (0.4.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in a:\python3\lib\site-packages (from botocore<1.28.0,>=1.27.82->boto3->transformers==2.2.0) (2.8.2)
# CPU times: total: 15.6 ms
# Wall time: 2.23 s

# %%
# %%time
# !pip install spacy==2.0.12
# Out:
# Collecting spacy==2.0.12
#   Using cached spacy-2.0.12.tar.gz (22.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.7 in a:\python3\lib\site-packages (from spacy==2.0.12) (1.23.1)
# Collecting murmurhash<0.29,>=0.28
#   Using cached murmurhash-0.28.0.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cymem<1.32,>=1.30
#   Using cached cymem-1.31.2.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting preshed<2.0.0,>=1.0.0
#   Using cached preshed-1.0.1.tar.gz (112 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting thinc<6.11.0,>=6.10.3
#   Using cached thinc-6.10.3.tar.gz (1.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting plac<1.0.0,>=0.9.6
#   Using cached plac-0.9.6-py2.py3-none-any.whl (20 kB)
# Collecting ujson>=1.35
#   Using cached ujson-5.5.0-cp310-cp310-win_amd64.whl (37 kB)
# Collecting dill<0.3,>=0.2
#   Using cached dill-0.2.9-py3-none-any.whl
# Collecting regex==2017.4.5
#   Using cached regex-2017.04.05.tar.gz (601 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in a:\python3\lib\site-packages (from spacy==2.0.12) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in a:\python3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in a:\python3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in a:\python3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in a:\python3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.12) (3.3)
# Collecting msgpack<1.0.0,>=0.5.6
#   Using cached msgpack-0.6.2-cp310-cp310-win_amd64.whl
# Collecting msgpack-numpy<1.0.0,>=0.4.1
#   Using cached msgpack_numpy-0.4.8-py2.py3-none-any.whl (6.9 kB)
# Collecting cytoolz<0.10,>=0.9.0
#   Using cached cytoolz-0.9.0.1.tar.gz (443 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in a:\python3\lib\site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (1.10.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in a:\python3\lib\site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (4.64.0)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in a:\python3\lib\site-packages (from thinc<6.11.0,>=6.10.3->spacy==2.0.12) (1.16.0)
# Requirement already satisfied: toolz>=0.8.0 in a:\python3\lib\site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy==2.0.12) (0.12.0)
# Requirement already satisfied: colorama in a:\python3\lib\site-packages (from tqdm<5.0.0,>=4.10.0->thinc<6.11.0,>=6.10.3->spacy==2.0.12) (0.4.5)
# Building wheels for collected packages: spacy, regex, cymem, murmurhash, preshed, thinc, cytoolz
#   Building wheel for spacy (setup.py): started
#   Building wheel for spacy (setup.py): finished with status 'error'
#   Running setup.py clean for spacy
#   Building wheel for regex (setup.py): started
#   Building wheel for regex (setup.py): finished with status 'error'
#   Running setup.py clean for regex
#   Building wheel for cymem (setup.py): started
#   Building wheel for cymem (setup.py): finished with status 'error'
#   Running setup.py clean for cymem
#   Building wheel for murmurhash (setup.py): started
#   Building wheel for murmurhash (setup.py): finished with status 'error'
#   Running setup.py clean for murmurhash
#   Building wheel for preshed (setup.py): started
#   Building wheel for preshed (setup.py): finished with status 'error'
#   Running setup.py clean for preshed
#   Building wheel for thinc (setup.py): started
#   Building wheel for thinc (setup.py): finished with status 'error'
#   Running setup.py clean for thinc
#   Building wheel for cytoolz (setup.py): started
#   Building wheel for cytoolz (setup.py): finished with status 'error'
#   Running setup.py clean for cytoolz
# Failed to build spacy regex cymem murmurhash preshed thinc cytoolz
# Installing collected packages: regex, plac, murmurhash, msgpack, cymem, ujson, preshed, msgpack-numpy, dill, cytoolz, thinc, spacy
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.7.25
#     Uninstalling regex-2022.7.25:
#       Successfully uninstalled regex-2022.7.25
#   Running setup.py install for regex: started
#   Running setup.py install for regex: finished with status 'error'
#   Rolling back uninstall of regex
#   Moving to a:\python3\lib\site-packages\regex-2022.7.25.dist-info\
#    from A:\Python3\Lib\site-packages\~egex-2022.7.25.dist-info
#   Moving to a:\python3\lib\site-packages\regex\
#    from A:\Python3\Lib\site-packages\~egex
# CPU times: total: 15.6 ms
# Wall time: 48.4 s
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [638 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   creating build\lib.win-amd64-3.10\spacy
#   copying spacy\about.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\compat.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\errors.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\glossary.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\language.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\lemmatizer.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\scorer.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\util.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\_ml.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\__init__.py -> build\lib.win-amd64-3.10\spacy
#   copying spacy\__main__.py -> build\lib.win-amd64-3.10\spacy
#   creating build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\convert.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\download.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\evaluate.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\info.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\init_model.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\link.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\package.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\profile.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\train.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\validate.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\vocab.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\_messages.py -> build\lib.win-amd64-3.10\spacy\cli
#   copying spacy\cli\__init__.py -> build\lib.win-amd64-3.10\spacy\cli
#   creating build\lib.win-amd64-3.10\spacy\data
#   copying spacy\data\__init__.py -> build\lib.win-amd64-3.10\spacy\data
#   creating build\lib.win-amd64-3.10\spacy\displacy
#   copying spacy\displacy\render.py -> build\lib.win-amd64-3.10\spacy\displacy
#   copying spacy\displacy\templates.py -> build\lib.win-amd64-3.10\spacy\displacy
#   copying spacy\displacy\__init__.py -> build\lib.win-amd64-3.10\spacy\displacy
#   creating build\lib.win-amd64-3.10\spacy\lang
#   copying spacy\lang\char_classes.py -> build\lib.win-amd64-3.10\spacy\lang
#   copying spacy\lang\entity_rules.py -> build\lib.win-amd64-3.10\spacy\lang
#   copying spacy\lang\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang
#   copying spacy\lang\norm_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang
#   copying spacy\lang\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang
#   copying spacy\lang\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang
#   copying spacy\lang\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang
#   copying spacy\lang\__init__.py -> build\lib.win-amd64-3.10\spacy\lang
#   creating build\lib.win-amd64-3.10\spacy\syntax
#   copying spacy\syntax\__init__.py -> build\lib.win-amd64-3.10\spacy\syntax
#   creating build\lib.win-amd64-3.10\spacy\tests
#   copying spacy\tests\conftest.py -> build\lib.win-amd64-3.10\spacy\tests
#   copying spacy\tests\test_matcher.py -> build\lib.win-amd64-3.10\spacy\tests
#   copying spacy\tests\test_misc.py -> build\lib.win-amd64-3.10\spacy\tests
#   copying spacy\tests\test_pickles.py -> build\lib.win-amd64-3.10\spacy\tests
#   copying spacy\tests\test_underscore.py -> build\lib.win-amd64-3.10\spacy\tests
#   copying spacy\tests\util.py -> build\lib.win-amd64-3.10\spacy\tests
#   copying spacy\tests\__init__.py -> build\lib.win-amd64-3.10\spacy\tests
#   creating build\lib.win-amd64-3.10\spacy\tokens
#   copying spacy\tokens\printers.py -> build\lib.win-amd64-3.10\spacy\tokens
#   copying spacy\tokens\underscore.py -> build\lib.win-amd64-3.10\spacy\tokens
#   copying spacy\tokens\__init__.py -> build\lib.win-amd64-3.10\spacy\tokens
#   creating build\lib.win-amd64-3.10\spacy\cli\converters
#   copying spacy\cli\converters\conllu2json.py -> build\lib.win-amd64-3.10\spacy\cli\converters
#   copying spacy\cli\converters\conllubio2json.py -> build\lib.win-amd64-3.10\spacy\cli\converters
#   copying spacy\cli\converters\conll_ner2json.py -> build\lib.win-amd64-3.10\spacy\cli\converters
#   copying spacy\cli\converters\iob2json.py -> build\lib.win-amd64-3.10\spacy\cli\converters
#   copying spacy\cli\converters\__init__.py -> build\lib.win-amd64-3.10\spacy\cli\converters
#   creating build\lib.win-amd64-3.10\spacy\lang\ar
#   copying spacy\lang\ar\examples.py -> build\lib.win-amd64-3.10\spacy\lang\ar
#   copying spacy\lang\ar\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\ar
#   copying spacy\lang\ar\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\ar
#   copying spacy\lang\ar\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\ar
#   copying spacy\lang\ar\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\ar
#   copying spacy\lang\ar\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\ar
#   creating build\lib.win-amd64-3.10\spacy\lang\bn
#   copying spacy\lang\bn\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\bn
#   copying spacy\lang\bn\morph_rules.py -> build\lib.win-amd64-3.10\spacy\lang\bn
#   copying spacy\lang\bn\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\bn
#   copying spacy\lang\bn\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\bn
#   copying spacy\lang\bn\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\bn
#   copying spacy\lang\bn\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\bn
#   copying spacy\lang\bn\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\bn
#   creating build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\examples.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\morph_rules.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\norm_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   copying spacy\lang\da\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\da
#   creating build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\examples.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\norm_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\syntax_iterators.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   copying spacy\lang\de\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\de
#   creating build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\examples.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\norm_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\tag_map_general.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   copying spacy\lang\el\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\el
#   creating build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\examples.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\morph_rules.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\norm_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\syntax_iterators.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   copying spacy\lang\en\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\en
#   creating build\lib.win-amd64-3.10\spacy\lang\es
#   copying spacy\lang\es\examples.py -> build\lib.win-amd64-3.10\spacy\lang\es
#   copying spacy\lang\es\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\es
#   copying spacy\lang\es\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\es
#   copying spacy\lang\es\syntax_iterators.py -> build\lib.win-amd64-3.10\spacy\lang\es
#   copying spacy\lang\es\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\es
#   copying spacy\lang\es\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\es
#   copying spacy\lang\es\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\es
#   creating build\lib.win-amd64-3.10\spacy\lang\fa
#   copying spacy\lang\fa\examples.py -> build\lib.win-amd64-3.10\spacy\lang\fa
#   copying spacy\lang\fa\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\fa
#   copying spacy\lang\fa\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\fa
#   creating build\lib.win-amd64-3.10\spacy\lang\fi
#   copying spacy\lang\fi\examples.py -> build\lib.win-amd64-3.10\spacy\lang\fi
#   copying spacy\lang\fi\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\fi
#   copying spacy\lang\fi\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\fi
#   copying spacy\lang\fi\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\fi
#   creating build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\examples.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\syntax_iterators.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   copying spacy\lang\fr\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\fr
#   creating build\lib.win-amd64-3.10\spacy\lang\ga
#   copying spacy\lang\ga\irish_morphology_helpers.py -> build\lib.win-amd64-3.10\spacy\lang\ga
#   copying spacy\lang\ga\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\ga
#   copying spacy\lang\ga\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\ga
#   copying spacy\lang\ga\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\ga
#   copying spacy\lang\ga\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\ga
#   creating build\lib.win-amd64-3.10\spacy\lang\he
#   copying spacy\lang\he\examples.py -> build\lib.win-amd64-3.10\spacy\lang\he
#   copying spacy\lang\he\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\he
#   copying spacy\lang\he\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\he
#   creating build\lib.win-amd64-3.10\spacy\lang\hi
#   copying spacy\lang\hi\examples.py -> build\lib.win-amd64-3.10\spacy\lang\hi
#   copying spacy\lang\hi\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\hi
#   copying spacy\lang\hi\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\hi
#   copying spacy\lang\hi\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\hi
#   creating build\lib.win-amd64-3.10\spacy\lang\hr
#   copying spacy\lang\hr\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\hr
#   copying spacy\lang\hr\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\hr
#   creating build\lib.win-amd64-3.10\spacy\lang\hu
#   copying spacy\lang\hu\examples.py -> build\lib.win-amd64-3.10\spacy\lang\hu
#   copying spacy\lang\hu\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\hu
#   copying spacy\lang\hu\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\hu
#   copying spacy\lang\hu\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\hu
#   copying spacy\lang\hu\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\hu
#   copying spacy\lang\hu\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\hu
#   creating build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\examples.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\norm_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\syntax_iterators.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   copying spacy\lang\id\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\id
#   creating build\lib.win-amd64-3.10\spacy\lang\it
#   copying spacy\lang\it\examples.py -> build\lib.win-amd64-3.10\spacy\lang\it
#   copying spacy\lang\it\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\it
#   copying spacy\lang\it\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\it
#   copying spacy\lang\it\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\it
#   copying spacy\lang\it\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\it
#   creating build\lib.win-amd64-3.10\spacy\lang\ja
#   copying spacy\lang\ja\examples.py -> build\lib.win-amd64-3.10\spacy\lang\ja
#   copying spacy\lang\ja\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\ja
#   copying spacy\lang\ja\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\ja
#   copying spacy\lang\ja\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\ja
#   creating build\lib.win-amd64-3.10\spacy\lang\nb
#   copying spacy\lang\nb\examples.py -> build\lib.win-amd64-3.10\spacy\lang\nb
#   copying spacy\lang\nb\morph_rules.py -> build\lib.win-amd64-3.10\spacy\lang\nb
#   copying spacy\lang\nb\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\nb
#   copying spacy\lang\nb\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\nb
#   copying spacy\lang\nb\syntax_iterators.py -> build\lib.win-amd64-3.10\spacy\lang\nb
#   copying spacy\lang\nb\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\nb
#   copying spacy\lang\nb\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\nb
#   copying spacy\lang\nb\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\nb
#   creating build\lib.win-amd64-3.10\spacy\lang\nl
#   copying spacy\lang\nl\examples.py -> build\lib.win-amd64-3.10\spacy\lang\nl
#   copying spacy\lang\nl\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\nl
#   copying spacy\lang\nl\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\nl
#   copying spacy\lang\nl\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\nl
#   copying spacy\lang\nl\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\nl
#   creating build\lib.win-amd64-3.10\spacy\lang\pl
#   copying spacy\lang\pl\examples.py -> build\lib.win-amd64-3.10\spacy\lang\pl
#   copying spacy\lang\pl\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\pl
#   copying spacy\lang\pl\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\pl
#   copying spacy\lang\pl\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\pl
#   creating build\lib.win-amd64-3.10\spacy\lang\pt
#   copying spacy\lang\pt\examples.py -> build\lib.win-amd64-3.10\spacy\lang\pt
#   copying spacy\lang\pt\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\pt
#   copying spacy\lang\pt\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\pt
#   copying spacy\lang\pt\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\pt
#   copying spacy\lang\pt\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\pt
#   copying spacy\lang\pt\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\pt
#   copying spacy\lang\pt\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\pt
#   creating build\lib.win-amd64-3.10\spacy\lang\ro
#   copying spacy\lang\ro\examples.py -> build\lib.win-amd64-3.10\spacy\lang\ro
#   copying spacy\lang\ro\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\ro
#   copying spacy\lang\ro\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\ro
#   copying spacy\lang\ro\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\ro
#   copying spacy\lang\ro\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\ro
#   copying spacy\lang\ro\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\ro
#   creating build\lib.win-amd64-3.10\spacy\lang\ru
#   copying spacy\lang\ru\examples.py -> build\lib.win-amd64-3.10\spacy\lang\ru
#   copying spacy\lang\ru\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\ru
#   copying spacy\lang\ru\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\ru
#   copying spacy\lang\ru\norm_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\ru
#   copying spacy\lang\ru\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\ru
#   copying spacy\lang\ru\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\ru
#   copying spacy\lang\ru\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\ru
#   copying spacy\lang\ru\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\ru
#   creating build\lib.win-amd64-3.10\spacy\lang\sv
#   copying spacy\lang\sv\examples.py -> build\lib.win-amd64-3.10\spacy\lang\sv
#   copying spacy\lang\sv\morph_rules.py -> build\lib.win-amd64-3.10\spacy\lang\sv
#   copying spacy\lang\sv\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\sv
#   copying spacy\lang\sv\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\sv
#   copying spacy\lang\sv\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\sv
#   creating build\lib.win-amd64-3.10\spacy\lang\th
#   copying spacy\lang\th\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\th
#   copying spacy\lang\th\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\th
#   copying spacy\lang\th\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\th
#   copying spacy\lang\th\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\th
#   creating build\lib.win-amd64-3.10\spacy\lang\tr
#   copying spacy\lang\tr\examples.py -> build\lib.win-amd64-3.10\spacy\lang\tr
#   copying spacy\lang\tr\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\tr
#   copying spacy\lang\tr\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\tr
#   copying spacy\lang\tr\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\tr
#   copying spacy\lang\tr\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\tr
#   copying spacy\lang\tr\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\tr
#   creating build\lib.win-amd64-3.10\spacy\lang\tt
#   copying spacy\lang\tt\examples.py -> build\lib.win-amd64-3.10\spacy\lang\tt
#   copying spacy\lang\tt\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\tt
#   copying spacy\lang\tt\punctuation.py -> build\lib.win-amd64-3.10\spacy\lang\tt
#   copying spacy\lang\tt\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\tt
#   copying spacy\lang\tt\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\tt
#   copying spacy\lang\tt\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\tt
#   creating build\lib.win-amd64-3.10\spacy\lang\ur
#   copying spacy\lang\ur\examples.py -> build\lib.win-amd64-3.10\spacy\lang\ur
#   copying spacy\lang\ur\lemmatizer.py -> build\lib.win-amd64-3.10\spacy\lang\ur
#   copying spacy\lang\ur\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\ur
#   copying spacy\lang\ur\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\ur
#   copying spacy\lang\ur\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\ur
#   copying spacy\lang\ur\tokenizer_exceptions.py -> build\lib.win-amd64-3.10\spacy\lang\ur
#   copying spacy\lang\ur\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\ur
#   creating build\lib.win-amd64-3.10\spacy\lang\vi
#   copying spacy\lang\vi\lex_attrs.py -> build\lib.win-amd64-3.10\spacy\lang\vi
#   copying spacy\lang\vi\stop_words.py -> build\lib.win-amd64-3.10\spacy\lang\vi
#   copying spacy\lang\vi\tag_map.py -> build\lib.win-amd64-3.10\spacy\lang\vi
#   copying spacy\lang\vi\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\vi
#   creating build\lib.win-amd64-3.10\spacy\lang\xx
#   copying spacy\lang\xx\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\xx
#   creating build\lib.win-amd64-3.10\spacy\lang\zh
#   copying spacy\lang\zh\examples.py -> build\lib.win-amd64-3.10\spacy\lang\zh
#   copying spacy\lang\zh\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\zh
#   creating build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\get_pos_from_wiktionary.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_adjectives_irreg.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_dets.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_dets_irreg.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_nouns.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_nouns_irreg.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_participles.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_proper_names.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_verbs.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\_verbs_irreg.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   copying spacy\lang\el\lemmatizer\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\el\lemmatizer
#   creating build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\lookup.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adjectives_irreg.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adverbs_irreg.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_nouns.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_nouns_irreg.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_verbs.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_verbs_irreg.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\en\lemmatizer
#   creating build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\lookup.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_adjectives_wordforms.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_adverbs_wordforms.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_nouns.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_nouns_wordforms.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_verbs.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\_verbs_wordforms.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   copying spacy\lang\nb\lemmatizer\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\nb\lemmatizer
#   creating build\lib.win-amd64-3.10\spacy\lang\sv\lemmatizer
#   copying spacy\lang\sv\lemmatizer\lookup.py -> build\lib.win-amd64-3.10\spacy\lang\sv\lemmatizer
#   copying spacy\lang\sv\lemmatizer\__init__.py -> build\lib.win-amd64-3.10\spacy\lang\sv\lemmatizer
#   creating build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\test_add_entities.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\test_array.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\test_creation.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\test_doc_api.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\test_pickle_doc.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\test_span.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\test_span_merge.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\test_token_api.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   copying spacy\tests\doc\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\doc
#   creating build\lib.win-amd64-3.10\spacy\tests\gold
#   copying spacy\tests\gold\test_biluo.py -> build\lib.win-amd64-3.10\spacy\tests\gold
#   copying spacy\tests\gold\test_lev_align.py -> build\lib.win-amd64-3.10\spacy\tests\gold
#   copying spacy\tests\gold\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\gold
#   creating build\lib.win-amd64-3.10\spacy\tests\lang
#   copying spacy\tests\lang\test_attrs.py -> build\lib.win-amd64-3.10\spacy\tests\lang
#   copying spacy\tests\lang\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\lang
#   creating build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_add_label.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_beam_parse.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_ner.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_neural_parser.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_nn_beam.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_nonproj.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_parse.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_parse_navigate.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_preset_sbd.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_space_attachment.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\test_to_from_bytes_disk.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   copying spacy\tests\parser\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\parser
#   creating build\lib.win-amd64-3.10\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_factories.py -> build\lib.win-amd64-3.10\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_pipe_methods.py -> build\lib.win-amd64-3.10\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_textcat.py -> build\lib.win-amd64-3.10\spacy\tests\pipeline
#   copying spacy\tests\pipeline\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\pipeline
#   creating build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue118.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1207.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1242.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1250.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1253.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1257.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1305.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1375.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1380.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1387.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1434.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1450.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1488.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1494.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1506.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1518.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1537.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1539.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1547.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1612.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1622.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1654.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1660.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1698.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1727.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1757.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1758.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1769.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1799.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1807.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1834.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1868.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1883.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1915.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1919.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1945.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1959.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1967.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue2179.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue2219.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue2361.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue2385.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue242.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue309.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue351.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue360.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue361.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue401.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue429.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue514.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue54.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue587.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue588.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue589.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue590.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue595.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue599.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue600.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue615.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue686.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue693.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue704.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue717.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue719.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue736.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue740.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue743.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue744.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue758.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue759.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue768.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue775.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue781.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue792.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue801.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue805.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue834.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue850.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue852.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue859.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue886.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue891.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue903.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue910.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue912.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue957.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue995.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\test_issue999.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   copying spacy\tests\regression\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\regression
#   creating build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialization.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_doc.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_empty_model.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_extension_attrs.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_language.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_parser_ner.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_stringstore.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tagger.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tensorizer.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tokenizer.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_vocab.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   copying spacy\tests\serialize\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\serialize
#   creating build\lib.win-amd64-3.10\spacy\tests\stringstore
#   copying spacy\tests\stringstore\test_freeze_string_store.py -> build\lib.win-amd64-3.10\spacy\tests\stringstore
#   copying spacy\tests\stringstore\test_stringstore.py -> build\lib.win-amd64-3.10\spacy\tests\stringstore
#   copying spacy\tests\stringstore\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\stringstore
#   creating build\lib.win-amd64-3.10\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_exceptions.py -> build\lib.win-amd64-3.10\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_naughty_strings.py -> build\lib.win-amd64-3.10\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_tokenizer.py -> build\lib.win-amd64-3.10\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_urls.py -> build\lib.win-amd64-3.10\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_whitespace.py -> build\lib.win-amd64-3.10\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\tokenizer
#   creating build\lib.win-amd64-3.10\spacy\tests\vectors
#   copying spacy\tests\vectors\test_similarity.py -> build\lib.win-amd64-3.10\spacy\tests\vectors
#   copying spacy\tests\vectors\test_vectors.py -> build\lib.win-amd64-3.10\spacy\tests\vectors
#   copying spacy\tests\vectors\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\vectors
#   creating build\lib.win-amd64-3.10\spacy\tests\vocab
#   copying spacy\tests\vocab\test_add_vectors.py -> build\lib.win-amd64-3.10\spacy\tests\vocab
#   copying spacy\tests\vocab\test_lexeme.py -> build\lib.win-amd64-3.10\spacy\tests\vocab
#   copying spacy\tests\vocab\test_vocab_api.py -> build\lib.win-amd64-3.10\spacy\tests\vocab
#   copying spacy\tests\vocab\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\vocab
#   creating build\lib.win-amd64-3.10\spacy\tests\lang\ar
#   copying spacy\tests\lang\ar\test_exceptions.py -> build\lib.win-amd64-3.10\spacy\tests\lang\ar
#   copying spacy\tests\lang\ar\test_text.py -> build\lib.win-amd64-3.10\spacy\tests\lang\ar
#   copying spacy\tests\lang\ar\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\lang\ar
#   creating build\lib.win-amd64-3.10\spacy\tests\lang\bn
#   copying spacy\tests\lang\bn\test_tokenizer.py -> build\lib.win-amd64-3.10\spacy\tests\lang\bn
#   copying spacy\tests\lang\bn\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\lang\bn
#   creating build\lib.win-amd64-3.10\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_exceptions.py -> build\lib.win-amd64-3.10\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_lemma.py -> build\lib.win-amd64-3.10\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.10\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_text.py -> build\lib.win-amd64-3.10\spacy\tests\lang\da
#   copying spacy\tests\lang\da\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\lang\da
#   creating build\lib.win-amd64-3.10\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_exceptions.py -> build\lib.win-amd64-3.10\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_lemma.py -> build\lib.win-amd64-3.10\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_models.py -> build\lib.win-amd64-3.10\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_parser.py -> build\lib.win-amd64-3.10\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.10\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_text.py -> build\lib.win-amd64-3.10\spacy\tests\lang\de
#   copying spacy\tests\lang\de\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\lang\de
#   creating build\lib.win-amd64-3.10\spacy\tests\lang\el
#   copying spacy\tests\lang\el\test_exception.py -> build\lib.win-amd64-3.10\spacy\tests\lang\el
#   copying spacy\tests\lang\el\test_text.py -> build\lib.win-amd64-3.10\spacy\tests\lang\el
#   copying spacy\tests\lang\el\__init__.py -> build\lib.win-amd64-3.10\spacy\tests\lang\el
#   creating build\lib.win-amd64-3.10\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_customized_tokenizer.py -> build\lib.win-amd64-3.10\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_exceptions.py -> build\lib.win-amd64-3.10\spacy\tests\lang\en
# ...
#   copying thinc\tests\unit\__init__.py -> build\lib.win-amd64-3.10\thinc\tests\unit
#   creating build\lib.win-amd64-3.10\thinc\tests\integration
#   copying thinc\tests\integration\test_affine_learns.py -> build\lib.win-amd64-3.10\thinc\tests\integration
#   copying thinc\tests\integration\test_basic_tagger.py -> build\lib.win-amd64-3.10\thinc\tests\integration
#   copying thinc\tests\integration\test_batch_norm.py -> build\lib.win-amd64-3.10\thinc\tests\integration
#   copying thinc\tests\integration\test_feed_forward.py -> build\lib.win-amd64-3.10\thinc\tests\integration
#   copying thinc\tests\integration\test_mnist.py -> build\lib.win-amd64-3.10\thinc\tests\integration
#   copying thinc\tests\integration\test_roundtrip_bytes.py -> build\lib.win-amd64-3.10\thinc\tests\integration
#   copying thinc\tests\integration\test_shape_check.py -> build\lib.win-amd64-3.10\thinc\tests\integration
#   copying thinc\tests\integration\__init__.py -> build\lib.win-amd64-3.10\thinc\tests\integration
#   creating build\lib.win-amd64-3.10\thinc\tests\linear
#   copying thinc\tests\linear\test_avgtron.py -> build\lib.win-amd64-3.10\thinc\tests\linear
#   copying thinc\tests\linear\test_linear.py -> build\lib.win-amd64-3.10\thinc\tests\linear
#   copying thinc\tests\linear\test_sparse_array.py -> build\lib.win-amd64-3.10\thinc\tests\linear
#   copying thinc\tests\linear\__init__.py -> build\lib.win-amd64-3.10\thinc\tests\linear
#   creating build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\__init__.py -> build\lib.win-amd64-3.10\thinc\linear
#   creating build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\mem.py -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\pooling.py -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\train.py -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\util.py -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\vec2vec.py -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\vecs2vec.py -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\vecs2vecs.py -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\_lsuv.py -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\__init__.py -> build\lib.win-amd64-3.10\thinc\neural
#   creating build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\datasets.py -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\hpbff.py -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\load_nlp.py -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\wrappers.py -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\__init__.py -> build\lib.win-amd64-3.10\thinc\extra
#   creating build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\affine.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\attention.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\batchnorm.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\convolution.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\difference.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\elu.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\embed.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\feed_forward.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\hash_embed.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\layernorm.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\lstm.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\maxout.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\model.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\relu.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\resnet.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\rnn.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\selu.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\softmax.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\static_vectors.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   copying thinc\neural\_classes\__init__.py -> build\lib.win-amd64-3.10\thinc\neural\_classes
#   creating build\lib.win-amd64-3.10\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_datasets.py -> build\lib.win-amd64-3.10\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_data_utils.py -> build\lib.win-amd64-3.10\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_generic_utils.py -> build\lib.win-amd64-3.10\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\__init__.py -> build\lib.win-amd64-3.10\thinc\extra\_vendorized
#   copying thinc\linalg.pyx -> build\lib.win-amd64-3.10\thinc
#   copying thinc\structs.pyx -> build\lib.win-amd64-3.10\thinc
#   copying thinc\typedefs.pyx -> build\lib.win-amd64-3.10\thinc
#   copying thinc\linalg.pxd -> build\lib.win-amd64-3.10\thinc
#   copying thinc\structs.pxd -> build\lib.win-amd64-3.10\thinc
#   copying thinc\typedefs.pxd -> build\lib.win-amd64-3.10\thinc
#   copying thinc\__init__.pxd -> build\lib.win-amd64-3.10\thinc
#   copying thinc\compile_time_constants.pxi -> build\lib.win-amd64-3.10\thinc
#   copying thinc\linalg.cpp -> build\lib.win-amd64-3.10\thinc
#   copying thinc\structs.cpp -> build\lib.win-amd64-3.10\thinc
#   copying thinc\typedefs.cpp -> build\lib.win-amd64-3.10\thinc
#   copying thinc\linear\avgtron.pyx -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\features.pyx -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\linear.pyx -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\serialize.pyx -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\sparse.pyx -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\avgtron.pxd -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\features.pxd -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\serialize.pxd -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\sparse.pxd -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\__init__.pxd -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\avgtron.cpp -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\features.cpp -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\linear.cpp -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\serialize.cpp -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\linear\sparse.cpp -> build\lib.win-amd64-3.10\thinc\linear
#   copying thinc\neural\gpu_ops.pyx -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\ops.pyx -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\optimizers.pyx -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\_funcs.pyx -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\ops.pxd -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\_funcs.pxd -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\__init__.pxd -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\gpu_ops.cpp -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\ops.cpp -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\optimizers.cpp -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\neural\_funcs.cpp -> build\lib.win-amd64-3.10\thinc\neural
#   copying thinc\extra\cache.pyx -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\eg.pyx -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\mb.pyx -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\search.pyx -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\cache.pxd -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\eg.pxd -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\mb.pxd -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\search.pxd -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\__init__.pxd -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\cache.cpp -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\eg.cpp -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\mb.cpp -> build\lib.win-amd64-3.10\thinc\extra
#   copying thinc\extra\search.cpp -> build\lib.win-amd64-3.10\thinc\extra
#   running build_ext
#   building 'thinc.linalg' extension
#   creating build\temp.win-amd64-3.10
#   creating build\temp.win-amd64-3.10\Release
#   creating build\temp.win-amd64-3.10\Release\thinc
#   C:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\BIN\x86_amd64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IA:\Python3\include -IC:\Users\Kunal\AppData\Local\Temp\pip-install-t8q9tscl\thinc_12622cf6f5e0465fa9f41a7226f7b318\include -IA:\Python3\include -IA:\Python3\Include -IC:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\INCLUDE -IC:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\ATLMFC\INCLUDE -IC:\Program Files (x86)\Windows Kits\10\include\10.0.10240.0\ucrt /EHsc /Tpthinc/linalg.cpp /Fobuild\temp.win-amd64-3.10\Release\thinc/linalg.obj /Ox /EHsc
#   linalg.cpp
#   a:\python3\include\pyconfig.h(200): fatal error C1083: Cannot open include file: 'basetsd.h': No such file or directory
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for thinc
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [55 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   creating build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\compatibility.py -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\utils_test.py -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\_signatures.py -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\_version.py -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\__init__.py -> build\lib.win-amd64-3.10\cytoolz
#   creating build\lib.win-amd64-3.10\cytoolz\curried
#   copying cytoolz\curried\exceptions.py -> build\lib.win-amd64-3.10\cytoolz\curried
#   copying cytoolz\curried\operator.py -> build\lib.win-amd64-3.10\cytoolz\curried
#   copying cytoolz\curried\__init__.py -> build\lib.win-amd64-3.10\cytoolz\curried
#   copying cytoolz\dicttoolz.pyx -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\functoolz.pyx -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\itertoolz.pyx -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\recipes.pyx -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\utils.pyx -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\cpython.pxd -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\dicttoolz.pxd -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\functoolz.pxd -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\itertoolz.pxd -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\recipes.pxd -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\utils.pxd -> build\lib.win-amd64-3.10\cytoolz
#   copying cytoolz\__init__.pxd -> build\lib.win-amd64-3.10\cytoolz
#   creating build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\dev_skip_test.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_compatibility.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_curried.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_curried_toolzlike.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_dev_skip_test.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_dicttoolz.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_docstrings.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_doctests.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_embedded_sigs.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_functoolz.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_inspect_args.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_itertoolz.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_none_safe.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_recipes.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_serialization.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_signatures.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_tlz.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   copying cytoolz\tests\test_utils.py -> build\lib.win-amd64-3.10\cytoolz\tests
#   running build_ext
#   building 'cytoolz.dicttoolz' extension
#   creating build\temp.win-amd64-3.10
#   creating build\temp.win-amd64-3.10\Release
#   creating build\temp.win-amd64-3.10\Release\cytoolz
#   C:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\BIN\x86_amd64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IA:\Python3\include -IA:\Python3\Include -IC:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\INCLUDE -IC:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\ATLMFC\INCLUDE -IC:\Program Files (x86)\Windows Kits\10\include\10.0.10240.0\ucrt /Tccytoolz/dicttoolz.c /Fobuild\temp.win-amd64-3.10\Release\cytoolz/dicttoolz.obj
#   dicttoolz.c
#   a:\python3\include\pyconfig.h(200): fatal error C1083: Cannot open include file: 'basetsd.h': No such file or directory
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for cytoolz
#   error: subprocess-exited-with-error
#
#   Running setup.py install for regex did not run successfully.
#   exit code: 1
#
#   [19 lines of output]
#   A:\Python3\lib\site-packages\setuptools\dist.py:487: UserWarning: Normalizing '2017.04.05' to '2017.4.5'
#     warnings.warn(tmpl.format(**locals()))
#   running install
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   copying Python3\regex.py -> build\lib.win-amd64-3.10
#   copying Python3\_regex_core.py -> build\lib.win-amd64-3.10
#   copying Python3\test_regex.py -> build\lib.win-amd64-3.10
#   running build_ext
#   building '_regex' extension
#   creating build\temp.win-amd64-3.10
#   creating build\temp.win-amd64-3.10\Release
#   creating build\temp.win-amd64-3.10\Release\Python3
#   C:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\BIN\x86_amd64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IA:\Python3\include -IA:\Python3\Include -IC:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\INCLUDE -IC:\Program Files (x86)\Microsoft Visual Studio 14.0\VC\ATLMFC\INCLUDE -IC:\Program Files (x86)\Windows Kits\10\include\10.0.10240.0\ucrt /TcPython3\_regex.c /Fobuild\temp.win-amd64-3.10\Release\Python3\_regex.obj
#   _regex.c
#   a:\python3\include\pyconfig.h(200): fatal error C1083: Cannot open include file: 'basetsd.h': No such file or directory
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# regex
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

from summarizer import TransformerSummarizer
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 7>()
#       4 import matplotlib
#       5 import matplotlib.pyplot as plt
# ----> 7 from summarizer import TransformerSummarizer
#       8 from sklearn.metrics import accuracy_score
#      10 import warnings
#
# File A:\Python3\lib\site-packages\summarizer\__init__.py:1, in <module>
# ----> 1 from summarizer.model_processors import Summarizer, TransformerSummarizer
#
# File A:\Python3\lib\site-packages\summarizer\model_processors.py:6, in <module>
#       3 import numpy as np
#       4 from transformers import *
# ----> 6 from summarizer.bert_parent import BertParent
#       7 from summarizer.cluster_features import ClusterFeatures
#       8 from summarizer.sentence_handler import SentenceHandler
#
# File A:\Python3\lib\site-packages\summarizer\bert_parent.py:9, in <module>
#       5 from numpy import ndarray
#       6 from transformers import *
# ----> 9 class BertParent(object):
#      11     """
#      12     Base handler for BERT models.
#      13     """
#      15     MODELS = {
#      16         'bert-base-uncased': (BertModel, BertTokenizer),
#      17         'bert-large-uncased': (BertModel, BertTokenizer),
#    (...)
#      22         'albert-large-v1': (AlbertModel, AlbertTokenizer)
#      23     }
#
# File A:\Python3\lib\site-packages\summarizer\bert_parent.py:16, in BertParent()
#       9 class BertParent(object):
#      11     """
#      12     Base handler for BERT models.
#      13     """
#      15     MODELS = {
# ---> 16         'bert-base-uncased': (BertModel, BertTokenizer),
#      17         'bert-large-uncased': (BertModel, BertTokenizer),
#      18         'xlnet-base-cased': (XLNetModel, XLNetTokenizer),
#      19         'xlm-mlm-enfr-1024': (XLMModel, XLMTokenizer),
#      20         'distilbert-base-uncased': (DistilBertModel, DistilBertTokenizer),
#      21         'albert-base-v1': (AlbertModel, AlbertTokenizer),
#      22         'albert-large-v1': (AlbertModel, AlbertTokenizer)
#      23     }
#      25     def __init__(
#      26         self,
#      27         model: str,
#      28         custom_model: PreTrainedModel=None,
#      29         custom_tokenizer: PreTrainedTokenizer=None
#      30     ):
#      31         """
#      32         :param model: Model is the string path for the bert weights. If given a keyword, the s3 path will be used.
#      33         :param custom_model: This is optional if a custom bert model is used.
#      34         :param custom_tokenizer: Place to use custom tokenizer.
#      35         """
#
# NameError: name 'BertModel' is not defined

# %% [markdown]
# ## 2. Download data <a class="anchor" id="2"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# Thanks to https://www.kaggle.com/vbmokin/nlp-for-en-bert-classification-for-water-report
df = pd.read_csv('../input/nlp-reports-news-classification/water_problem_nlp_en_for_Kaggle_100.csv', delimiter=';', header=0)
df = df.fillna(0)

convert_dict = {'text': str, 
                'env_problems': int,
                'pollution': int, 
                'treatment': int,
                'climate': int,
                'biomonitoring': int} 
  
df = df.astype(convert_dict)
df = df[:5]
df

# %%
df.info()

# %%
df['text'].head(10)

# %%
df['text'].str.len().max()

# %%
# Creation the list with new long block
max_length = 400  # minimum characters in each block
i = 0
bodies = []
while i < len(df):
    body = ""
    body_empty = True
    while (len(body) < max_length) and (i < len(df)):
        if body_empty:
            body = df.loc[i,'text']
            body_empty = False
        else: body += " " + df.loc[i,'text']
        i += 1
    bodies.append(body)
    print("Length of blocks =", len(body))
print(f"\nNumber of text blocks = {len(bodies)}\n")
print("Text blocks:\n", bodies)

# %% [markdown]
# ## 3. Text Summarizing <a class="anchor" id="3"></a>
#
# [Back to Table of Contents](#0.1)

# %%
min_length_text = 40

# %% [markdown]
# ### 3.1. BERT Summarizing <a class="anchor" id="3.1"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# %%time
bert_summary = []
for i in range(len(bodies)):
    bert_model = Summarizer()
    bert_summary.append(''.join(bert_model(bodies[i], min_length=min_length_text)))

# %% [markdown]
# ### 3.2. GPT-2 Summarizing <a class="anchor" id="3.2"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# %%time
gpt_summary = []
for i in range(len(bodies)):
    GPT2_model = TransformerSummarizer(transformer_type="GPT2",transformer_model_key="gpt2-medium")
    gpt_summary.append(''.join(GPT2_model(bodies[i], min_length=min_length_text)))

# %% [markdown]
# ### 3.3. XLNet Summarizing <a class="anchor" id="3.3"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# %%time
xlnet_summary = []
for i in range(len(bodies)):
    model = TransformerSummarizer(transformer_type="XLNet",transformer_model_key="xlnet-base-cased")
    xlnet_summary.append(''.join(model(bodies[i], min_length=min_length_text)))

# %% [markdown]
# ## 4. Results <a class="anchor" id="4"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# %%time
print("All Summarizing Results:\n")
for i in range(len(bodies)):
    print("ORIGINAL TEXT:")
    print(bodies[i])
    print("\nBERT Summarizing Result:")
    print(bert_summary[i])
    print("\nGPT-2 Summarizing Result:")
    print(gpt_summary[i])
    print("\nXLNet Summarizing Result:")
    print(xlnet_summary[i])
    print("\n\n")

# %% [markdown]
# I hope you find this notebook useful and enjoyable.

# %% [markdown]
# Your comments and feedback are most welcome.

# %% [markdown]
# [Go to Top](#0)
